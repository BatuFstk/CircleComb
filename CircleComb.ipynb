# %%
import numpy as np
import matplotlib.pyplot as plt


num_samples = 1000
radius = 5
theta = np.random.uniform(0, 2*np.pi, num_samples)
class_0_x = radius * np.cos(theta)
class_0_y = radius * np.sin(theta)

radius = 10
theta = np.random.uniform(0, 2*np.pi, num_samples)
class_1_x = radius * np.cos(theta)
class_1_y = radius * np.sin(theta)


class_0_label = np.zeros(num_samples)
class_1_label = np.ones(num_samples)


X = np.concatenate([np.vstack([class_0_x, class_0_y]).T, np.vstack([class_1_x, class_1_y]).T])
y = np.concatenate([class_0_label, class_1_label])


indices = np.arange(X.shape[0])
np.random.shuffle(indices)
X = X[indices]
y = y[indices]


plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm, s=20)
plt.title('Dairesel Sınıra Sahip Veri Seti')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()



from keras.models import Sequential
from keras.layers import Dense


model = Sequential()
model.add(Dense(8, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))


model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X, y, epochs=100, batch_size=10)


_, accuracy = model.evaluate(X, y)
print('Model Doğruluğu:', accuracy)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 2s 4ms/step - loss: 0.9753 - accuracy: 0.4860
# Epoch 2/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6354 - accuracy: 0.5190
# Epoch 3/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5625 - accuracy: 0.6210
# Epoch 4/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5255 - accuracy: 0.6930
# Epoch 5/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4931 - accuracy: 0.8230
# Epoch 6/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4603 - accuracy: 0.8875
# Epoch 7/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4274 - accuracy: 0.9060
# Epoch 8/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3944 - accuracy: 0.9315
# Epoch 9/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3619 - accuracy: 0.9540
# Epoch 10/100
# ...
